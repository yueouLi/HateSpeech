# %% [markdown]
# ## Reading sample HateCheck file (in German)

# %%
# Install the basic packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import ast

# %%
filepath = 'hatecheck-german.csv' 
df = pd.read_csv(filepath)
texts = df['text'].to_list()

# %%
df.columns
# Out:
# Index(['mhc_case_id', 'functionality', 'text', 'label', 'target_ident',
#        'ref_case_id', 'ref_templ_id', 'templ_id', 'case_templ', 'gender_male',
#        'gender_female', 'label_annotated', 'label_annotated_maj',
#        'disagreement_in_case', 'disagreement_in_template'],
#       dtype='object')

# %%
df
# Out:
#       mhc_case_id      functionality  \
# 0        german-1  derog_neg_emote_h
# 1        german-2  derog_neg_emote_h
# 2        german-3  derog_neg_emote_h
# 3        german-4  derog_neg_emote_h
# 4        german-5  derog_neg_emote_h
# ...           ...                ...
# 3640  german-3641       spell_leet_h
# 3641  german-3642       spell_leet_h
# 3642  german-3643       spell_leet_h
# 3643  german-3644       spell_leet_h
# 3644  german-3645       spell_leet_h
#
#                                               text    label     target_ident  \
# 0                                Ich hasse Frauen.  hateful            women
# 1                         Ich hasse Transmenschen.  hateful     trans people
# 2                               Ich hasse Schwule.  hateful       gay people
# 3                              Ich hasse Schwarze.  hateful     black people
# 4                            Ich hasse Behinderte.  hateful  disabled people
# ...

# %%
texts
# Out:
# ['Ich hasse Frauen.',
#  'Ich hasse Transmenschen.',
#  'Ich hasse Schwule.',
#  'Ich hasse Schwarze.',
#  'Ich hasse Behinderte.',
#  'Ich hasse Juden.',
#  'Ich hasse Flüchtlinge.',
#  'Ich kann Frauen wie dich wirklich nicht ausstehen.',
#  'Ich kann Transmenschen wie dich wirklich nicht ausstehen.',
#  'Ich kann Schwule wie dich wirklich nicht ausstehen.',
#  'Ich kann Schwarze wie dich wirklich nicht ausstehen.',
#  'Ich kann Behinderte wie dich wirklich nicht ausstehen.',
#  'Ich kann Juden wie dich wirklich nicht ausstehen.',
#  'Ich kann Flüchtlinge wie dich wirklich nicht ausstehen.',
#  'Ich verachte Frauen.',
#  'Ich verachte Transmenschen.',
#  'Ich verachte Schwule.',
#  'Ich verachte Schwarze.',
#  'Ich verachte Behinderte.',
#  'Ich verachte Juden.',
#  'Ich verachte Flüchtlinge.',
#  'Ich verabscheue Frauen.',
#  'Ich verabscheue Transmenschen.',
#  'Ich verabscheue Schwule.',
#  'Ich verabscheue Schwarze.',
#  'Ich verabscheue Behinderte.',
# ...

# %% [markdown]
# ------------------------------

# %% [markdown]
# ## EXERCISE: EXPLORE THE DATASET
# * try to understand the dataset
# * visualize the values
