# %% [markdown]
# ## GAZE4HATE (Project-2 and Project-3)
# ### Reading the files

# %%
# Install the basic packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import ast

# %%
# Reading Gaze4Hate Original Sentences
orig_sentence_file = "gaze4hate_sentences_to_annotate.xlsx"
orig_sent_df = pd.read_excel(open(orig_sentence_file, 'rb'), sheet_name='stimuli')

# %%
orig_sent_df

# %% [markdown]
# ## EXERCISE:
# * Try to implement one of the python annotation library (PIGEON or TORTUS) to annotate this data
# * annotate 90 sentences (whether the positive or negative statements are implicitly or explicitly made)
# * save the annotation file as csv

# %% [markdown]
# ----------------------------

# %% [markdown]
# # Reading the word-level measures (including gaze measurements)

# %%
## Gaze4Hate dataset
filename = "gaze4hate_processed_data_word_level.csv"
gaze_df = pd.read_csv(filename)#
gaze_df.drop(gaze_df.filter(regex="Unname"), axis=1, inplace=True)
gaze_df.head(5)
# Out:
#   RECORDING_SESSION_LABEL  TRIAL_INDEX  IA_AVERAGE_FIX_PUPIL_SIZE  \
# 0                      p1            5                     931.00
# 1                      p1            5                     950.00
# 2                      p1            5                     901.00
# 3                      p1            5                     945.50
# 4                      p1            5                     946.43
#
#    IA_FIXATION_%  IA_FIXATION_COUNT  IA_DWELL_TIME  IA_DWELL_TIME_%  \
# 0         0.1000                  3            732           0.1122
# 1         0.1000                  3            499           0.0765
# 2         0.1000                  3            454           0.0696
# 3         0.2000                  6           1727           0.2648
# 4         0.2333                  7           1535           0.2354
#
#    IA_FIRST_FIXATION_DURATION IA_LABEL  IA_MAX_FIX_PUPIL_SIZE  ...  \
# 0                       150.0   Word 1                  963.0  ...
# 1                       157.0   Word 2                 1002.0  ...
# 2                       157.0   Word 3                  928.0  ...
# 3                       174.0   Word 4                 1005.0  ...
# 4                       145.0   Word 5                 1043.0  ...
#
#                                            assertion  Gender[1]  \
# 0  Frauen haben einen signifikant geringeren Durc...     female
# 1  Frauen haben einen signifikant geringeren Durc...     female
# 2  Frauen haben einen signifikant geringeren Durc...     female
# 3  Frauen haben einen signifikant geringeren Durc...     female
# 4  Frauen haben einen signifikant geringeren Durc...     female
#
#    IA_SECOND_FIXATION_DURATION  IA_SECOND_RUN_FIXATION_%  \
# 0                        320.0                    0.0333
# 1                        167.0                    0.0333
# 2                        155.0                    0.0333
# 3                        286.0                    0.0333
# 4                        240.0                    0.0667
#
#    IA_FIRST_RUN_FIXATION_%  Clicked        token  Intensity_Category  \
# 0                   0.0333    False       frauen                hate
# 1                   0.0333    False        haben                hate
# 2                   0.0333    False        einen                hate
# 3                   0.0333     True  signifikant                hate
# 4                   0.0667     True   geringeren                hate
#
#   Intensity_Category_Binary  Pupilsize_variation
# 0                      hate                 68.0
# 1                      hate                111.0
# 2                      hate                 55.0
# 3                      hate                146.0
# 4                      hate                166.0
#
# [5 rows x 34 columns]

# %%
gaze_df['RECORDING_SESSION_LABEL'].unique().tolist()
# Out:
# ['p1',
#  'p10',
#  'p11',
#  'p12',
#  'p13',
#  'p14',
#  'p15',
#  'p17',
#  'p18',
#  'p19',
#  'p2',
#  'p20',
#  'p21',
#  'p22',
#  'p23',
#  'p24',
#  'p25',
#  'p26',
#  'p27',
#  'p28',
#  'p29',
#  'p3',
#  'p30',
#  'p31',
#  'p32',
#  'p33',
#  'p34',
#  'p35',
#  'p36',
#  'p37',
#  'p38',
#  'p39',
#  'p4',
#  'p40',
#  'p41',
#  'p42',
#  'p43',
#  'p44',
#  'p45',
#  'p5',
#  'p6',
#  'p7',
#  'p9']

# %% [markdown]
# ## EXERCISE:
# * try to understand the dataset and explore the values in each column
